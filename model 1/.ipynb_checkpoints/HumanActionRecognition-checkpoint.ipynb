# %% [markdown]
# # Import Libraries

# %%
import warnings
warnings.filterwarnings("ignore")

import os
import gc
import cv2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from lib_file import lib_path
import random
import seaborn as sns
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import tensorflow as tf

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
BASE_DIR = "input"

class_labels = os.listdir(BASE_DIR)
class_labels.sort()

print(class_labels)
# Out:
# ['basketball', 'biking', 'diving', 'golf_swing', 'horse_riding']

# %%
video_paths = []
targets = []

for target in tqdm(class_labels):
    target_path = os.path.join(BASE_DIR, target)
    sub_target_folders = os.listdir(target_path)
    for subfolder in sub_target_folders:
        if str(subfolder).lower() != "annotation":
            sub_target_folder_path = os.path.join(target_path, subfolder)
            video_files = os.listdir(sub_target_folder_path)
            video_files = [os.path.join(sub_target_folder_path, file_) for file_ in video_files]
            video_paths.extend(video_files)
            targets.extend([target]*len(video_files))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 224.38it/s]

# %%
df = pd.DataFrame()
df['video_paths'] = video_paths
df['targets'] = targets

df.head()
# Out:
#                                          video_paths     targets
# 0  input\basketball\v_shooting_01\v_shooting_01_0...  basketball
# 1  input\basketball\v_shooting_01\v_shooting_01_0...  basketball
# 2  input\basketball\v_shooting_01\v_shooting_01_0...  basketball
# 3  input\basketball\v_shooting_01\v_shooting_01_0...  basketball
# 4  input\basketball\v_shooting_01\v_shooting_01_0...  basketball

# %%
df.tail()
# Out:
#                                            video_paths       targets
# 777  input\horse_riding\v_riding_25\v_riding_25_19.avi  horse_riding
# 778  input\horse_riding\v_riding_25\v_riding_25_20.avi  horse_riding
# 779  input\horse_riding\v_riding_25\v_riding_25_21.avi  horse_riding
# 780  input\horse_riding\v_riding_25\v_riding_25_22.avi  horse_riding
# 781  input\horse_riding\v_riding_25\v_riding_25_23.avi  horse_riding

# %%
df.shape
# Out:
# (782, 2)

# %%
df['targets'].value_counts()
# Out:
# horse_riding    198
# diving          156
# biking          145
# golf_swing      142
# basketball      141
# Name: targets, dtype: int64

# %%
chart_data = dict(df['targets'].value_counts())
with plt.style.context(style="fivethirtyeight"):
    plt.figure(figsize=(8,5))
    plt.rcParams['font.size'] = 15
    plt.bar(x=list(chart_data.keys()),
           height=list(chart_data.values()))
    plt.title(label="Bar-chart with 'targets' feature", fontsize=20)
    plt.xlabel(xlabel="Targets", fontsize=15)
    plt.ylabel(ylabel="Number of samples", fontsize=15)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
    for x, y in zip(chart_data.keys(), chart_data.values()):
        plt.text(x, y, str(y), ha='center', va='bottom')
    plt.show()

# %%
chart_data = dict(df['targets'].value_counts())
with plt.style.context(style="fivethirtyeight"):
    plt.figure(figsize=(8,5))
    plt.rcParams['font.size'] = 15
    plt.pie(labels=list(chart_data.keys()),
           x=list(chart_data.values()),
           autopct="%.2f%%")
    plt.title(label="Pie-chart with 'targets' feature", fontsize=20)
    plt.show()

# %%
class_dict = {}
for idx, label in enumerate(class_labels):
    class_dict[label] = idx

print(class_dict)
# Out:
# {'basketball': 0, 'biking': 1, 'diving': 2, 'golf_swing': 3, 'horse_riding': 4}

# %%
df['targets'] = df['targets'].map(class_dict)
df.head()
# Out:
#                                          video_paths  targets
# 0  input\basketball\v_shooting_01\v_shooting_01_0...        0
# 1  input\basketball\v_shooting_01\v_shooting_01_0...        0
# 2  input\basketball\v_shooting_01\v_shooting_01_0...        0
# 3  input\basketball\v_shooting_01\v_shooting_01_0...        0
# 4  input\basketball\v_shooting_01\v_shooting_01_0...        0

# %%
df = df.sample(frac=1).reset_index(drop=True)
df.head()
# Out:
#                                          video_paths  targets
# 0  input\horse_riding\v_riding_02\v_riding_02_04.avi        4
# 1  input\horse_riding\v_riding_01\v_riding_01_05.avi        4
# 2        input\biking\v_biking_13\v_biking_13_02.avi        1
# 3        input\diving\v_diving_01\v_diving_01_06.avi        2
# 4        input\biking\v_biking_06\v_biking_06_05.avi        1

# %% [markdown]
# # Data Loading

# %%
data_length = 20
image_height = 96
image_width = 96
frames = []
target_labels = []

for video_path, numerical_label in tqdm(zip(df['video_paths'].values.tolist(), df['targets'].values.tolist()), total=len(df)):
    video_reader = cv2.VideoCapture(video_path)
    video_frames_count = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))
    if video_frames_count >= data_length:
        skip_frames_window = max(int(video_frames_count / data_length), 1)
        frames_list = []
        for frame_counter in range(data_length):
            target_frame_position = round(frame_counter * skip_frames_window)
            video_reader.set(cv2.CAP_PROP_POS_FRAMES, target_frame_position)
            success, frame = video_reader.read()
            if not success:
                break
            resized_frame = cv2.resize(frame, (image_height, image_width))
            normalized_frame = resized_frame / 255.0
            frames_list.append(normalized_frame)
        video_reader.release()
        frames.append(np.array(frames_list))
        target_labels.append(numerical_label)
    else:
        continue
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 782/782 [00:40<00:00, 19.21it/s]

# %%
frames = np.asarray(frames)
print(frames.shape)
# Out:
# (778, 20, 96, 96, 3)

# %%
random_state = 42
num_frames_to_select = 16
num_videos = frames.shape[0]
random_video_indices = np.random.choice(num_videos, num_frames_to_select, replace=False)

fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(10, 10))
axes_flat = axes.flatten()

for i, video_index in enumerate(random_video_indices):
    ax = axes_flat[i]
    random_frame_index = np.random.choice(frames[video_index].shape[0], 1)[0]
    frame = frames[video_index][random_frame_index]
    target_name = class_labels[target_labels[video_index]]
    frame= cv2.normalize(frame, None, 0, 255, cv2.NORM_MINMAX)
    frame = frame.astype(np.uint8)
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    ax.imshow(frame)
    ax.set_title(f'Target: {target_name}')
    ax.axis("off")

plt.tight_layout()
plt.show()

# %%
frames = np.asarray(frames)
target_labels = tf.keras.utils.to_categorical(target_labels)

print(frames.shape)
print(target_labels.shape)
# Out:
# (778, 20, 96, 96, 3)
# (778, 5)

# %% [markdown]
# # Data Splitting

# %%
X_train, X_val, y_train, y_val = train_test_split(frames, target_labels, test_size=0.1, random_state=42)
print(X_train.shape, X_val.shape, y_train.shape, y_val.shape)

# %%
del frames
del target_labels
gc.collect()
# Out:
# 3786

# %% [markdown]
# # Algorithm: ConvolutionalLongShort-TermMemory

# %%
model = tf.keras.Sequential()

model.add(tf.keras.layers.Input(shape=(data_length, image_height, image_width, 3)))

model.add(tf.keras.layers.ConvLSTM2D(filters = 32, kernel_size = (3, 3), activation = 'tanh',data_format = "channels_last",recurrent_dropout=0.2, return_sequences=True))
model.add(tf.keras.layers.MaxPool3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))

model.add(tf.keras.layers.ConvLSTM2D(filters = 64, kernel_size = (3, 3), activation = 'tanh', data_format = "channels_last",recurrent_dropout=0.2, return_sequences=True))
model.add(tf.keras.layers.MaxPool3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))

model.add(tf.keras.layers.ConvLSTM2D(filters = 128, kernel_size = (3, 3), activation = 'tanh', data_format = "channels_last",recurrent_dropout=0.2, return_sequences=True))
model.add(tf.keras.layers.MaxPool3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))

model.add(tf.keras.layers.ConvLSTM2D(filters = 256, kernel_size = (3, 3), activation = 'tanh', data_format = "channels_last",recurrent_dropout=0.2, return_sequences=True))
model.add(tf.keras.layers.MaxPool3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))

model.add(tf.keras.layers.ConvLSTM2D(filters = 512, kernel_size = (3, 3), activation = 'tanh', data_format = "channels_last",recurrent_dropout=0.2, return_sequences=True))
model.add(tf.keras.layers.MaxPool3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))

model.add(tf.keras.layers.ConvLSTM2D(filters = 512, kernel_size = (2, 2), activation = 'tanh', data_format = "channels_last",recurrent_dropout=0.2, return_sequences=True))
model.add(tf.keras.layers.MaxPool3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))

model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dropout(0.4))

model.add(tf.keras.layers.Dense(units=512))
model.add(tf.keras.layers.Dense(units=len(class_labels), activation = "softmax"))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv_lstm2d (ConvLSTM2D)    (None, 20, 94, 94, 32)    40448
#
#  max_pooling3d (MaxPooling3  (None, 20, 47, 47, 32)    0
#  D)
#
#  conv_lstm2d_1 (ConvLSTM2D)  (None, 20, 45, 45, 64)    221440
#
#  max_pooling3d_1 (MaxPoolin  (None, 20, 23, 23, 64)    0
#  g3D)
#
#  conv_lstm2d_2 (ConvLSTM2D)  (None, 20, 21, 21, 128)   885248
#
#  max_pooling3d_2 (MaxPoolin  (None, 20, 11, 11, 128)   0
#  g3D)
#
#  conv_lstm2d_3 (ConvLSTM2D)  (None, 20, 9, 9, 256)     3539968
#
#  max_pooling3d_3 (MaxPoolin  (None, 20, 5, 5, 256)     0
#  g3D)
#
#  conv_lstm2d_4 (ConvLSTM2D)  (None, 20, 3, 3, 512)     14157824
#
#  max_pooling3d_4 (MaxPoolin  (None, 20, 2, 2, 512)     0
#  g3D)
#
#  conv_lstm2d_5 (ConvLSTM2D)  (None, 20, 1, 1, 512)     8390656
#
#  max_pooling3d_5 (MaxPoolin  (None, 20, 1, 1, 512)     0
#  g3D)
#
#  flatten (Flatten)           (None, 10240)             0
#
#  dropout (Dropout)           (None, 10240)             0
#
#  dense (Dense)               (None, 512)               5243392
#
#  dense_1 (Dense)             (None, 5)                 2565
#
# =================================================================
# Total params: 32481541 (123.91 MB)
# Trainable params: 32481541 (123.91 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',  optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), metrics=["accuracy"])

# %% [markdown]
# # Model Training

# %%
EPOCHS = 50

history = model.fit(x=X_train,
                    y=y_train,
                    epochs=EPOCHS,
                    batch_size=4,
                    validation_split=0.2,
                    callbacks=[tf.keras.callbacks.ReduceLROnPlateau(monitor="val_accuracy", patience=2, min_lr=0)])
# Out:
# Epoch 1/50
# 140/140 [==============================] - 61s 302ms/step - loss: 1.4600 - accuracy: 0.3429 - val_loss: 1.4733 - val_accuracy: 0.4143 - lr: 1.0000e-04
# Epoch 2/50
# 140/140 [==============================] - 40s 284ms/step - loss: 1.2358 - accuracy: 0.4446 - val_loss: 1.1144 - val_accuracy: 0.5214 - lr: 1.0000e-04
# Epoch 3/50
# 140/140 [==============================] - 40s 287ms/step - loss: 0.9471 - accuracy: 0.6357 - val_loss: 0.8744 - val_accuracy: 0.6500 - lr: 1.0000e-04
# Epoch 4/50
# 140/140 [==============================] - 40s 285ms/step - loss: 0.7773 - accuracy: 0.6714 - val_loss: 0.7441 - val_accuracy: 0.7000 - lr: 1.0000e-04
# Epoch 5/50
# 140/140 [==============================] - 40s 286ms/step - loss: 0.5832 - accuracy: 0.7839 - val_loss: 0.9615 - val_accuracy: 0.6643 - lr: 1.0000e-04
# Epoch 6/50
# 140/140 [==============================] - 40s 287ms/step - loss: 0.5459 - accuracy: 0.7857 - val_loss: 0.6512 - val_accuracy: 0.7429 - lr: 1.0000e-04
# Epoch 7/50
# 140/140 [==============================] - 40s 284ms/step - loss: 0.4340 - accuracy: 0.8304 - val_loss: 0.6134 - val_accuracy: 0.8071 - lr: 1.0000e-04
# Epoch 8/50
# 140/140 [==============================] - 40s 288ms/step - loss: 0.2955 - accuracy: 0.8857 - val_loss: 0.5969 - val_accuracy: 0.7714 - lr: 1.0000e-04
# Epoch 9/50
# 140/140 [==============================] - 40s 285ms/step - loss: 0.2210 - accuracy: 0.9179 - val_loss: 0.5350 - val_accuracy: 0.8071 - lr: 1.0000e-04
# Epoch 10/50
# 140/140 [==============================] - 40s 286ms/step - loss: 0.1201 - accuracy: 0.9768 - val_loss: 0.5258 - val_accuracy: 0.8429 - lr: 1.0000e-05
# Epoch 11/50
# 140/140 [==============================] - 40s 286ms/step - loss: 0.0740 - accuracy: 0.9839 - val_loss: 0.5669 - val_accuracy: 0.8214 - lr: 1.0000e-05
# Epoch 12/50
# 140/140 [==============================] - 40s 285ms/step - loss: 0.0565 - accuracy: 0.9911 - val_loss: 0.6330 - val_accuracy: 0.8214 - lr: 1.0000e-05
# Epoch 13/50
# 140/140 [==============================] - 40s 288ms/step - loss: 0.0441 - accuracy: 0.9911 - val_loss: 0.6273 - val_accuracy: 0.8214 - lr: 1.0000e-06
# Epoch 14/50
# 140/140 [==============================] - 40s 285ms/step - loss: 0.0414 - accuracy: 0.9929 - val_loss: 0.6273 - val_accuracy: 0.8357 - lr: 1.0000e-06
# Epoch 15/50
# 140/140 [==============================] - 40s 285ms/step - loss: 0.0391 - accuracy: 0.9929 - val_loss: 0.6275 - val_accuracy: 0.8357 - lr: 1.0000e-07
# Epoch 16/50
# 140/140 [==============================] - 40s 286ms/step - loss: 0.0385 - accuracy: 0.9929 - val_loss: 0.6277 - val_accuracy: 0.8357 - lr: 1.0000e-07
# Epoch 17/50
# 140/140 [==============================] - 40s 285ms/step - loss: 0.0383 - accuracy: 0.9929 - val_loss: 0.6277 - val_accuracy: 0.8357 - lr: 1.0000e-08
# Epoch 18/50
# 140/140 [==============================] - 40s 287ms/step - loss: 0.0401 - accuracy: 0.9929 - val_loss: 0.6278 - val_accuracy: 0.8357 - lr: 1.0000e-08
# Epoch 19/50
# 140/140 [==============================] - 40s 285ms/step - loss: 0.0396 - accuracy: 0.9929 - val_loss: 0.6278 - val_accuracy: 0.8357 - lr: 1.0000e-09
# Epoch 20/50
# 140/140 [==============================] - 40s 286ms/step - loss: 0.0402 - accuracy: 0.9911 - val_loss: 0.6278 - val_accuracy: 0.8357 - lr: 1.0000e-09
# Epoch 21/50
# 140/140 [==============================] - 40s 286ms/step - loss: 0.0388 - accuracy: 0.9929 - val_loss: 0.6278 - val_accuracy: 0.8357 - lr: 1.0000e-10
# Epoch 22/50
# 140/140 [==============================] - 40s 284ms/step - loss: 0.0406 - accuracy: 0.9929 - val_loss: 0.6278 - val_accuracy: 0.8357 - lr: 1.0000e-10
# Epoch 23/50
# 140/140 [==============================] - 40s 288ms/step - loss: 0.0398 - accuracy: 0.9929 - val_loss: 0.6278 - val_accuracy: 0.8357 - lr: 1.0000e-11
# Epoch 24/50
# 140/140 [==============================] - 40s 283ms/step - loss: 0.0408 - accuracy: 0.9929 - val_loss: 0.6278 - val_accuracy: 0.8357 - lr: 1.0000e-11
# Epoch 25/50
# 140/140 [==============================] - 40s 286ms/step - loss: 0.0398 - accuracy: 0.9929 - val_loss: 0.6278 - val_accuracy: 0.8357 - lr: 1.0000e-12
# Epoch 26/50
# 140/140 [==============================] - 40s 285ms/step - loss: 0.0399 - accuracy: 0.9929 - val_loss: 0.6278 - val_accuracy: 0.8357 - lr: 1.0000e-12
# Epoch 27/50
# 140/140 [==============================] - 40s 285ms/step - loss: 0.0390 - accuracy: 0.9929 - val_loss: 0.6278 - val_accuracy: 0.8357 - lr: 1.0000e-13
# Epoch 28/50
# 140/140 [==============================] - 40s 286ms/step - loss: 0.0401 - accuracy: 0.9929 - val_loss: 0.6278 - val_accuracy: 0.8357 - lr: 1.0000e-13
# Epoch 29/50
# 140/140 [==============================] - 40s 284ms/step - loss: 0.0393 - accuracy: 0.9929 - val_loss: 0.6278 - val_accuracy: 0.8357 - lr: 1.0000e-14
# Epoch 30/50
# 140/140 [==============================] - 40s 286ms/step - loss: 0.0376 - accuracy: 0.9929 - val_loss: 0.6278 - val_accuracy: 0.8357 - lr: 1.0000e-14
# Epoch 31/50
# 140/140 [==============================] - 40s 286ms/step - loss: 0.0403 - accuracy: 0.9929 - val_loss: 0.6278 - val_accuracy: 0.8357 - lr: 1.0000e-15
# Epoch 32/50
# 140/140 [==============================] - 40s 282ms/step - loss: 0.0394 - accuracy: 0.9929 - val_loss: 0.6278 - val_accuracy: 0.8357 - lr: 1.0000e-15
# Epoch 33/50
# 140/140 [==============================] - 40s 286ms/step - loss: 0.0392 - accuracy: 0.9929 - val_loss: 0.6278 - val_accuracy: 0.8357 - lr: 1.0000e-16
# Epoch 34/50
# 140/140 [==============================] - 40s 286ms/step - loss: 0.0394 - accuracy: 0.9929 - val_loss: 0.6278 - val_accuracy: 0.8357 - lr: 1.0000e-16
# Epoch 35/50
# 140/140 [==============================] - 40s 287ms/step - loss: 0.0384 - accuracy: 0.9929 - val_loss: 0.6278 - val_accuracy: 0.8357 - lr: 1.0000e-17
# Epoch 36/50
# 140/140 [==============================] - 40s 286ms/step - loss: 0.0411 - accuracy: 0.9929 - val_loss: 0.6278 - val_accuracy: 0.8357 - lr: 1.0000e-17
# Epoch 37/50
# 140/140 [==============================] - 40s 284ms/step - loss: 0.0387 - accuracy: 0.9929 - val_loss: 0.6278 - val_accuracy: 0.8357 - lr: 1.0000e-18
# Epoch 38/50
# 140/140 [==============================] - 40s 288ms/step - loss: 0.0392 - accuracy: 0.9929 - val_loss: 0.6278 - val_accuracy: 0.8357 - lr: 1.0000e-18
# Epoch 39/50
# 140/140 [==============================] - 40s 284ms/step - loss: 0.0417 - accuracy: 0.9929 - val_loss: 0.6278 - val_accuracy: 0.8357 - lr: 1.0000e-19
# Epoch 40/50
# 140/140 [==============================] - 40s 286ms/step - loss: 0.0385 - accuracy: 0.9911 - val_loss: 0.6278 - val_accuracy: 0.8357 - lr: 1.0000e-19
# Epoch 41/50
# 140/140 [==============================] - 40s 285ms/step - loss: 0.0378 - accuracy: 0.9929 - val_loss: 0.6278 - val_accuracy: 0.8357 - lr: 1.0000e-20
# Epoch 42/50
# 140/140 [==============================] - 40s 285ms/step - loss: 0.0410 - accuracy: 0.9929 - val_loss: 0.6278 - val_accuracy: 0.8357 - lr: 1.0000e-20
# Epoch 43/50
# 140/140 [==============================] - 40s 286ms/step - loss: 0.0416 - accuracy: 0.9929 - val_loss: 0.6278 - val_accuracy: 0.8357 - lr: 1.0000e-21
# Epoch 44/50
# 140/140 [==============================] - 40s 283ms/step - loss: 0.0382 - accuracy: 0.9929 - val_loss: 0.6278 - val_accuracy: 0.8357 - lr: 1.0000e-21
# Epoch 45/50
# 140/140 [==============================] - 40s 285ms/step - loss: 0.0395 - accuracy: 0.9929 - val_loss: 0.6278 - val_accuracy: 0.8357 - lr: 1.0000e-22
# Epoch 46/50
# 140/140 [==============================] - 40s 286ms/step - loss: 0.0408 - accuracy: 0.9929 - val_loss: 0.6278 - val_accuracy: 0.8357 - lr: 1.0000e-22
# Epoch 47/50
# 140/140 [==============================] - 40s 285ms/step - loss: 0.0405 - accuracy: 0.9929 - val_loss: 0.6278 - val_accuracy: 0.8357 - lr: 1.0000e-23
# Epoch 48/50
# 140/140 [==============================] - 40s 286ms/step - loss: 0.0407 - accuracy: 0.9911 - val_loss: 0.6278 - val_accuracy: 0.8357 - lr: 1.0000e-23
# Epoch 49/50
# 140/140 [==============================] - 40s 283ms/step - loss: 0.0396 - accuracy: 0.9929 - val_loss: 0.6278 - val_accuracy: 0.8357 - lr: 1.0000e-24
# Epoch 50/50
# 140/140 [==============================] - 40s 286ms/step - loss: 0.0407 - accuracy: 0.9929 - val_loss: 0.6278 - val_accuracy: 0.8357 - lr: 1.0000e-24

# %%
fig,axes=plt.subplots(nrows=2,ncols=1,figsize=(15,10))
plt.rcParams["font.size"]=15
axes[0].plot(history.history['accuracy'],label='Accuracy',marker='o')
axes[0].plot(history.history['val_accuracy'],label='Val_Accuracy',marker='o')
axes[0].set_title(label='Accuracy plot-graphs')
axes[0].set_xlabel(xlabel='Epochs')
axes[0].set_ylabel(ylabel='Accuracy')
axes[0].legend()
axes[0].grid()
axes[1].plot(history.history['loss'],label='Loss',marker='o')
axes[1].plot(history.history['val_loss'],label='Val_Loss',marker='o')
axes[1].set_title(label='Loss plot-graphs')
axes[1].set_xlabel(xlabel='Epochs')
axes[1].set_ylabel(ylabel='Loss')
axes[1].legend()
axes[1].grid()
fig.tight_layout()
plt.show()

# %% [markdown]
# # Model Prediction

# %%
model_probs = model.predict(X_val, verbose=1)
print(model_probs)
# Out:
# 3/3 [==============================] - 3s 326ms/step
# [[4.80206795e-02 5.54828439e-04 9.51424479e-01 2.11192237e-08
#   3.54306984e-08]
#  [1.16561912e-03 3.75573453e-03 1.20050493e-06 3.74445459e-03
#   9.91332948e-01]
#  [2.27503733e-05 1.10231103e-05 1.30241318e-09 2.43510641e-07
#   9.99966025e-01]
#  [1.39378046e-03 1.08858821e-07 6.74963800e-08 9.97265339e-01
#   1.34064758e-03]
#  [9.99983549e-01 1.20115806e-10 2.45685305e-10 4.17169849e-06
#   1.22346619e-05]
#  [6.70930822e-05 8.85715783e-01 4.81954085e-05 2.31437240e-04
#   1.13937534e-01]
#  [9.78181371e-04 1.18856353e-03 2.42614277e-07 3.84214392e-04
#   9.97448742e-01]
#  [5.80871289e-12 1.38004616e-11 1.36308126e-11 1.00000000e+00
#   2.99743258e-10]
#  [4.63538617e-02 7.02321180e-04 6.34482467e-06 3.60453292e-03
#   9.49332952e-01]
#  [2.46717373e-05 3.23366791e-01 2.28445492e-06 7.72975269e-04
#   6.75833285e-01]
#  [1.51028991e-01 3.19433808e-02 8.17019343e-01 2.01026964e-07
#   8.07326251e-06]
#  [4.92706778e-04 2.07329877e-02 6.53893039e-06 1.44049376e-02
#   9.64362800e-01]
#  [1.70859433e-08 3.44130890e-10 4.24442348e-08 1.00000000e+00
#   1.04977471e-09]
#  [9.41379368e-03 3.89006027e-06 2.79914598e-08 3.55631718e-03
#   9.87025917e-01]
#  [9.11040340e-12 2.59086606e-11 2.50129171e-11 1.00000000e+00
#   5.23822985e-10]
#  [6.64146006e-01 2.22242321e-03 3.02375364e-03 3.30259860e-01
#   3.47905647e-04]
#  [1.25860490e-04 2.57007461e-02 2.81283906e-06 9.94479284e-03
#   9.64225769e-01]
#  [8.55427861e-05 1.60194047e-09 1.86464337e-08 9.99914408e-01
#   1.59558855e-09]
#  [1.01545602e-05 1.68174356e-02 5.20917456e-06 3.54148506e-05
#   9.83131766e-01]]

# %%
model_labels=np.argmax(model_probs, axis=1)
print(model_labels.tolist())
# Out:
# [2, 4, 4, 3, 0, 1, 4, 3, 4, 4, 2, 4, 3, 4, 0, 4, 0, 4, 0, 4, 4, 4, 1, 4, 0, 2, 3, 4, 0, 3, 4, 4, 0, 1, 3, 0, 1, 2, 2, 3, 0, 0, 2, 1, 4, 0, 0, 4, 2, 3, 1, 0, 2, 0, 0, 1, 2, 1, 3, 2, 0, 0, 4, 4, 0, 4, 2, 4, 0, 4, 3, 2, 4, 3, 0, 4, 3, 4]

# %%
true_labels=np.argmax(y_val,axis=1)
print(true_labels.tolist())
# Out:
# [2, 4, 4, 3, 0, 1, 4, 3, 4, 1, 2, 3, 3, 4, 0, 4, 3, 4, 0, 4, 4, 4, 1, 4, 0, 2, 3, 4, 0, 3, 4, 4, 0, 4, 3, 1, 1, 2, 2, 3, 0, 0, 2, 2, 4, 0, 0, 4, 2, 1, 0, 0, 2, 0, 0, 1, 2, 1, 3, 2, 0, 0, 0, 3, 0, 4, 2, 1, 0, 4, 3, 2, 1, 3, 1, 4, 3, 4]

# %% [markdown]
# # Result Analysis

# %% [markdown]
# ***Accuracy Score***

# %%
model_accuracy=accuracy_score(y_true=true_labels,y_pred=model_labels)
print(f"Validation accuracy of ConvolutionalLongShort-TermMemory model is {model_accuracy*100.0:.2f}%")
# Out:
# Validation accuracy of ConvolutionalLongShort-TermMemory model is 83.33%

# %% [markdown]
# ***Classification Report***

# %%
print(classification_report(y_true=true_labels, y_pred=model_labels, target_names=class_labels))
# Out:
#               precision    recall  f1-score   support
#
#   basketball       0.85      0.89      0.87        19
#       biking       0.62      0.45      0.53        11
#       diving       1.00      0.92      0.96        13
#   golf_swing       0.92      0.79      0.85        14
# horse_riding       0.77      0.95      0.85        21
#
#     accuracy                           0.83        78
#    macro avg       0.83      0.80      0.81        78
# weighted avg       0.83      0.83      0.83        78

# %% [markdown]
# ***Confusion Matrix***

# %%
plt.figure(figsize=(5,5))
plt.rcParams['font.size']=15
sns.heatmap(data=confusion_matrix(y_true=true_labels,y_pred=model_labels),
            cmap=plt.cm.Blues,
            annot=True,
            fmt='4d',
            cbar=False,
            linecolor='black',
            linewidths=0.5,
            xticklabels=class_labels,
            yticklabels=class_labels)
plt.title(label='Confusion Matrix')
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.show()

# %% [markdown]
# # Model Saving

# %%
model.save(filepath='model/ConvolutionalLongShortTermMemory_model.h5')
